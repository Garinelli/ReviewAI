# %%
import pandas as pd

# %%
df = pd.read_csv('main_df.csv')

# %%
df
# Out:
#       Unnamed: 0                                        User review  \
# 0            0.0  Достоинства\r\n       все устроило нормальная ...
# 1            1.0  Шикарная, начиталась отзывы, но рискнула, что ...
# 2            2.0                                  Дочке понравилась
# 3            3.0                  Пока не одевала ,но то что хотела
# 4            4.0                                    Отличная куртка
# ...          ...                                                ...
# 1792        94.0                      Все супер, продукт на высоте.
# 1793        95.0            Товар рекомендую, все на высшем уровне.
# 1794        96.0  Не ожидал такого высокого качества, покупкой д...
# 1795        97.0       Все замечательно, продукт оправдал ожидания.
# 1796        98.0                   Рекомендую товар, куплю еще раз.
#
#      Review date  Star review  Text length  Has media  Has answer  \
# 0     2024-10-09            5           54          0           0
# ...
