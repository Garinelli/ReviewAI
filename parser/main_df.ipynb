# %%
import pandas as pd

# %%
df = pd.read_csv('main_df.csv')

# %%
df
# Out:
#       Unnamed: 0                                        User review  \
# 0            0.0  Упаковано просто в пакет, думала верхнюю одежд...
# 1            1.0                                    лёгкая,красивая
# 2            2.0  Общее впечатление- красивая, удобная. Купила д...
# 3            3.0                           Нормальная, на прогулки.
# 4            4.0  Как для профессионала швейного дела куртка и п...
# ...          ...                                                ...
# 1779        94.0                      Все супер, продукт на высоте.
# 1780        95.0            Товар рекомендую, все на высшем уровне.
# 1781        96.0  Не ожидал такого высокого качества, покупкой д...
# 1782        97.0       Все замечательно, продукт оправдал ожидания.
# 1783        98.0                   Рекомендую товар, куплю еще раз.
#
#      Review date  Star review  Text length  Has media  Written by bot  \
# 0     2024-10-01            1          373          0               0
# ...
