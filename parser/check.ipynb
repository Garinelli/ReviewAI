# %%
import pandas as pd

# %%
df = pd.read_csv('dataframe.csv')

# %%
df
# Out:
#      Unnamed: 0                                        User review  \
# 0             0  Достоинства\n       все устроило нормальная де...
# 1             1  Шикарная, начиталась отзывы, но рискнула, что ...
# 2             2                                  Дочке понравилась
# 3             3                  Пока не одевала ,но то что хотела
# 4             4                                    Отличная куртка
# ..          ...                                                ...
# 622         622            Нету связи и никто не может дозвониться
# 623         623  Пока пользуюсь только 2 недели,за это время ,п...
# 624         624                                              Фигня
# 625         625                              Достоинства\n       .
# 626         626                                                  👍
#
#     Review date  Star review  Text length  Has media  Has answer  \
# 0    2024-10-09            5           54          0           0
# ...
