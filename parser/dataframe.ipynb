# %%
import pandas as pd

df = pd.read_csv('dataframe.csv')

# %%
df
# Out:
#      Unnamed: 0     User name  \
# 0             0  Александр Ф.
# 1             1       Иван А.
# 2             2   Владимир Б.
# 3             3     Алишер Т.
# 4             4   Виолетта И.
# ..          ...           ...
# 602         602      Лидия Г.
# 603         603       No data
# 604         604  Екатерина Г.
# 605         605  Анастасия А.
# 606         606   Светлана С.
#
#                                            User review  \
# 0    Качество великолепное. Формы пошива отличные. ...
# 1                                            Качество👍
# 2    Отлично, ориг, Вьетнам. Лого вышит. У меня L, ...
# 3             Пришло с каким-то петном маленькая дырка
# 4                   Толстовка супер, качество хорошее.
# ..                                                 ...
# 602                                            No data
# 603                                            No data
# 604                                            No data
# ...
