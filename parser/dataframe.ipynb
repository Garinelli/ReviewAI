# %%
import pandas as pd

df = pd.read_csv('dataframe.csv')

# %%
df
# Out:
#      Unnamed: 0     User name  \
# 0             0     Сергей С.
# 1             1    Наталья А.
# 2             2     Михаил Я.
# 3             3      Елена К.
# 4             4     Лариса П.
# ..          ...           ...
# 612         612      Лидия Г.
# 613         613       No data
# 614         614  Екатерина Г.
# 615         615  Анастасия А.
# 616         616   Светлана С.
#
#                                            User review  \
# 0                                   Куртка понравилась
# 1                                                Супер
# 2    Девушка довольна, легкая, воздушная, для осени...
# 3               Курта легкая, симпатичная, понравилась
# 4    Куртка супер!!! Нашла такую же в белом цвете у...
# ..                                                 ...
# 612                                            No data
# 613                                            No data
# 614                                            No data
# ...

# %%
len(df)
# Out:
# 617
