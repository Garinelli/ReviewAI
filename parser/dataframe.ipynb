# %%
import pandas as pd

df = pd.read_csv('dataframe.csv')

# %%
df
# Out:
#      Unnamed: 0     User name                                  User review  \
# 0             0      Ольга Х.            Классный ! На лето замечательно )
# 1             1    Татьяна С.                             Топчик - топчик!
# 2             2    Эльвира Б.  Не пончла какой он, подарила младшей сестре
# 3             3      Alina P.                               Приятная ткань
# 4             4      Алиса Г.                                  Хороший топ
# ..          ...           ...                                          ...
# 115         115      Павел В.                           Хорошего качества!
# 116         116      Денис К.                                    Синтетика
# 117         117     Михаил К.                             Хорошее качество
# 118         118  Александр П.                 Все отлично, сели как влитые
# 119         119  Александр П.                  Отличные носки. Все подошло
#
#           Review date  Star review  Text length
# ...
