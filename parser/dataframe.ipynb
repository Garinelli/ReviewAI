# %%
import pandas as pd

df = pd.read_csv('dataframe.csv')

# %%
df
# Out:
#      Unnamed: 0   User name  \
# 0             0    Ольга Х.
# 1             1  Татьяна С.
# 2             2  Эльвира Б.
# 3             3    Alina P.
# 4             4    Алиса Г.
# ..          ...         ...
# 96           96      Фиалка
# 97           97     No data
# 98           98   Максим Ж.
# 99           99     No data
# 100         100   Михаил Т.
#
#                                            User review       Review date  \
# 0                    Классный ! На лето замечательно )  18 сентября 2024
# 1                                     Топчик - топчик!  17 сентября 2024
# 2          Не пончла какой он, подарила младшей сестре   31 августа 2024
# 3                                       Приятная ткань   21 августа 2024
# 4                                          Хороший топ   15 августа 2024
# ..                                                 ...               ...
# 96   Хорошая футболка, пользуюсь много лет, форму и...  14 сентября 2024
# ...
