# %%
import pandas as pd

df = pd.read_csv('dataframe.csv')

# %%
df
# Out:
#      Unnamed: 0                                        User review  \
# 0             0  Упаковано просто в пакет, думала верхнюю одежд...
# 1             1                                    лёгкая,красивая
# 2             2  Общее впечатление- красивая, удобная. Купила д...
# 3             3                           Нормальная, на прогулки.
# 4             4  Как для профессионала швейного дела куртка и п...
# ..          ...                                                ...
# 609         609                     Сыну понравился,пока работает)
# 610         610  Телефон конечно г полное) \nЕсли только бабушк...
# 611         611                 Отличный телефон. Ребенок счастлив
# 612         612  Мне понравилось!!! Дальше видно будет,пока все...
# 613         613  Обалденное впечатление! Начиная от упаковки, з...
#
#     Review date  Star review  Text length  Has media  Written by bot
# 0    2024-10-01            1          373          0               0
# ...

# %%
len(df)
# Out:
# 637
