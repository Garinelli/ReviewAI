# %%
import pandas as pd

# %%
fake_df = pd.read_csv('fake_reviews.csv')

# %%
fake_df
# Out:
#     Unnamed: 0                                        User review Review date  \
# 0            0  Отличный товар, всем рекомендую! Качество на в...  2024-09-30
# 1            1  Превзошло все мои ожидания! Советую всем друзьям.  2024-09-29
# 2            2  Купил и остался доволен, за такие деньги лучше...  2024-09-28
# 3            3  Очень хорошее качество, всем советую этот прод...  2024-09-27
# 4            4       Заказываю не первый раз, всегда всё отлично.  2024-09-26
# ..         ...                                                ...         ...
# 94          94                      Все супер, продукт на высоте.  2024-06-28
# 95          95            Товар рекомендую, все на высшем уровне.  2024-06-27
# 96          96  Не ожидал такого высокого качества, покупкой д...  2024-06-26
# 97          97       Все замечательно, продукт оправдал ожидания.  2024-06-25
# 98          98                   Рекомендую товар, куплю еще раз.  2024-06-24
#
# ...
