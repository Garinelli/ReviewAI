# %%
import pandas as pd

df = pd.read_csv('dataframe.csv')

# %%
df
# Out:
#      Unnamed: 0                                        User review  \
# 0             0  Упаковано просто в пакет, думала верхнюю одежд...
# 1             1                                    лёгкая,красивая
# 2             2  Общее впечатление- красивая, удобная. Купила д...
# 3             3                           Нормальная, на прогулки.
# 4             4  Как для профессионала швейного дела куртка и п...
# ..          ...                                                ...
# 609         609                     Сыну понравился,пока работает)
# 610         610  Телефон конечно г полное) \nЕсли только бабушк...
# 611         611                 Отличный телефон. Ребенок счастлив
# 612         612  Мне понравилось!!! Дальше видно будет,пока все...
# 613         613  Обалденное впечатление! Начиная от упаковки, з...
#
#     Review date  Star review  Text length  Has media  Written by bot
# 0    2024-10-01            1          373          0               0
# ...

# %%
from tensorflow.keras import layers, regularizers, Sequential
import tensorflow as tf 
maxlen = 100

# Токенизация и подготовка текстовых данных
tokenizer = Tokenizer(num_words=max_features)
tokenizer.fit_on_texts(user_reviews)
sequences = tokenizer.texts_to_sequences(user_reviews)
padded_sequences = pad_sequences(sequences, maxlen=maxlen)

# Вход для текстовых данных
text_input = tf.keras.Input(shape=(maxlen,), name='text_input')
x_text = layers.Embedding(max_features + 1, embedding_dim)(text_input)
x_text = layers.GlobalAveragePooling1D()(x_text)
x_text = layers.Dense(64, activation='relu')(x_text)

# Вход для числовых данных
num_input = tf.keras.Input(shape=(num_features,), name='num_input')
x_num = layers.Dense(32, activation='relu')(num_input)

# Объединение текстовых и числовых данных
combined = layers.Concatenate()([x_text, x_num])

# основное тело нейросети
x = layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.01))(combined)
x = layers.Dropout(0.1)(x)
x = layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.01))(x)
x = layers.Dropout(0.1)(x)
x = layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.01))(x)
x = layers.Dropout(0.1)(x)

output = layers.Dense(2, activation='softmax')(x)

model = tf.keras.Model(inputs=[text_input, num_input], outputs=output)

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()

# Использование LSTM
text_input = tf.keras.Input(shape=(maxlen,), name='text_input')
x_text = layers.Embedding(max_features + 1, embedding_dim)(text_input)
x_text = layers.LSTM(64, return_sequences=False)(x_text)  
x_text = layers.Dense(64, activation='relu')(x_text)

# Использование GRU
text_input = tf.keras.Input(shape=(maxlen,), name='text_input')
x_text = layers.Embedding(max_features + 1, embedding_dim)(text_input)
x_text = layers.GRU(64, return_sequences=False)(x_text) 
x_text = layers.Dense(64, activation='relu')(x_text)
# Out:
# 637
